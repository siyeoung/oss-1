# %%
x=0
print(x)
print(type(x))

x=10.5
print(x)
print(type(x))

x="shxung"
print(x)
print(type(x))

x=True
print(x)
print(type(x))
# Out:
# 0
# <class 'int'>
# 10.5
# <class 'float'>
# hong
# <class 'str'>
# True
# <class 'bool'>

# %%
name= "siyeong's" #siyeong's
print(name)

print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
print(name[5])
print(name[6])
print('jang')
# Out:
# siyeong's
# s
# i
# y
# e
# o
# n
# g
# jang

# %%
a=100
b="100"

print(a==b)

c=str(a)+b
print(c)
# Out:
# False
# 100100

# %%
num=int(input("정수를 입력하세요 >>"))
#num=int("100")=>100
print(type(num))
print(num)

num=float(input("정수를 입력하세요 >>"))
#num=int("100")=>100
print(type(num))
print(num)
# Out:
# 정수를 입력하세요 >>100
# <class 'int'>
# 100
# 정수를 입력하세요 >>100
# <class 'float'>
# 100.0

# %%
print("나는 현재 "+str(21)+ "살 입니다")
# Out:
# 나는 현재 21살 입니다

# %%
print("안녕하세요?")
name=input("이름이  어떻게 되시나요?")
print("만나서 반갑습니다." +name + "씨")

print("이름의 길이는 다음과 같군요 : ", len(name))

age=int(input("나이가 어떻게 되나요?"))
print("내년에는 " + str(age+1)+ "이 되시는군요.")
# Out:
# 안녕하세요?
# 이름이  어떻게 되시나요?시영
# 만나서 반갑습니다.시영씨
# 이름의 길이는 다음과 같군요 :  2
# 나이가 어떻게 되나요?21
# 내년에는 22이 되시는군요.

# %%
print("="*20)
print("성적프로그램")
print("작성자 : 장시영")
print("="*20)
# Out:
# ...
# 성적프로그램
# 작성자 : 장시영
# ...

# %%
print("jang" in "hello world")
# Out:
# False

# %%
text="  hello      World    "
print(text.count('o'))
print(text.lower())
print(text.upper())
print(text.strip())
print(text.lstrip())
print(text.rstrip())
print(text.replace("  ",""))
# Out:
# 2
#   hello      world
#   HELLO      WORLD
# hello      World
# hello      World
#   hello      World
# helloWorld

# %%
product="coffee"
count=3
price=1000
print(f"상품{product} {count}개의 가격은 {count*price}원입니다.")
print("상품", product, count, "개의 가격은 "+ str(count*price)+"원입니다.")
print("상품 %s %d개의 가격은 %d원입니다." %(product, count, count*price))
# Out:
# 상품coffee 3개의 가격은 3000원입니다.
# 상품 coffee 3 개의 가격은 3000원입니다.
# 상품 coffee 3개의 가격은 3000원입니다.
